# %% [markdown]
# ## Task 1
# * Replace null values 'Age' column with ffill().
# * Replace null values in 'Cabin and 'Embarked' columns with most occured value

# %%
import pandas as pa
import numpy as nu

# %%
ship = pa.read_csv('https://raw.githubusercontent.com/nagamounika5/Datasets/master/titanic.csv')
ship
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#Replace null values 'Age' column with ffill().
ship['Age'].fillna(method = 'ffill', inplace = True)
ship
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#Replace null values in 'Cabin and 'Embarked' columns with most occured value
ship['Cabin'].value_counts()
# Out:
# C23 C25 C27        4
# B96 B98            4
# G6                 4
# E101               3
# C22 C26            3
# F2                 3
# D                  3
# F33                3
# B77                2
# D17                2
# D33                2
# E33                2
# C126               2
# B49                2
# C52                2
# B51 B53 B55        2
# D20                2
# B58 B60            2
# B57 B59 B63 B66    2
# C83                2
# B5                 2
# C92                2
# D26                2
# C125               2
# C78                2
# C65                2
# D35                2
# E8                 2
# E121               2
# B35                2
#                   ..
# C118               1
# C85                1
# B30                1
# B69                1
# C62 C64            1
# C30                1
# B39                1
# A23                1
# D56                1
# E40                1
# C46                1
# D48                1
# ...

# %%
ship['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
ship["Cabin"].fillna("G6", inplace = True)
ship
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
ship["Embarked"].fillna("S", inplace = True)
ship
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## Task2:
# - After handling missing values, Convert Cabin, Embarked columns into numerical columns

# %%
from sklearn.preprocessing import LabelEncoder
la = LabelEncoder()

ship['Embarked'] = la.fit_transform(ship['Embarked'])
ship
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
ship['Cabin'] = la.fit_transform(ship['Cabin'])
ship
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## Task3:
# - Display the plot of original data and robust scaler data
# - Plot of the original data

# %%
ship['Name'] = la.fit_transform(ship['Name'])
ship['Sex'] = la.fit_transform(ship['Sex'])
ship['Ticket'] = la.fit_transform(ship['Ticket'])
ship
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1  22.0      1      0     523
# 1              2         1       1   190    0  38.0      1      0     596
# 2              3         1       3   353    0  26.0      0      0     669
# 3              4         1       1   272    0  35.0      1      0      49
# 4              5         0       3    15    1  35.0      0      0     472
# 5              6         0       3   554    1  35.0      0      0     275
# 6              7         0       1   515    1  54.0      0      0      85
# 7              8         0       3   624    1   2.0      3      1     395
# 8              9         1       3   412    0  27.0      0      2     344
# 9             10         1       2   576    0  14.0      1      0     132
# 10            11         1       3   727    0   4.0      1      1     616
# 11            12         1       1    95    0  58.0      0      0      38
# ...

# %%
import seaborn as sns
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
rs = RobustScaler()
ship.plot(kind='hist')

# %%
z = rs.fit_transform(ship)
z1 = pa.DataFrame(z, columns = ship.columns)
z1.plot(kind='hist')
